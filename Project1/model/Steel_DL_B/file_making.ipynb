# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, RobustScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import ADASYN
import numpy as np
import joblib
from sklearn import metrics
from scikeras.wrappers import KerasClassifier

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers as Layer
from tensorflow.keras.metrics import Recall, Precision, BinaryAccuracy, TruePositives, TrueNegatives, FalsePositives, FalseNegatives
from tensorflow.keras.regularizers import L1L2
from timeit import default_timer as timer
import json

# %%
def load_data(csv_path='https://raw.githubusercontent.com/urmd1f/Project1/main/data/steel.csv', scaler=None, upsampling=None, TEST_SIZE=0.2, VAL_SIZE=0.2, RANDOM_STATE=42):

    # 글로벌로 만들어서 저장하기
    global df, X, y, X_train, X_val, X_test, y_train, y_val, y_test
    
    df = pd.read_csv(csv_path)

    # 이상치 전처리 
    # 일단 카피 
    df_clear = df.copy()
    # 타겟특성 빼고 변수에 저장
    df_clear = df_clear.drop(df_clear.iloc[:,-7:].columns, axis=1)
    # Area라는 컬럼 생성
    df_clear['Area'] = (df['X_Maximum'] - df['X_Minimum']) * (df['Y_Maximum'] - df['Y_Minimum'])
    # Area컬럼을 생성하는데 사용된 피쳐 제거(X_Maximum, X_Minimum, Y_Maximum, Y_Minimum)
    df_clear = df_clear.drop(df.iloc[:, :4].columns, axis=1)
    # A300 제거(300 or 400이라 하나 제거 후 컬럼명 어떻게 할지 고민)
    df_clear = df_clear.drop('TypeOfSteel_A300', axis=1)
    # 일단 TypeOfSteel로만 변경해서 설명란에 0은 300 1은 400으로 해보기로
    df_clear.rename(columns={'TypeOfSteel_A400':'TypeOfSteel'}, inplace=True)
    # Log_X_index, Log_Y_index 제거 LogOFAreas가 합친결과값으로 판단되어 제거하기로 함
    df_clear = df_clear.drop(['Log_X_Index', 'Log_Y_Index'], axis=1)
    df_clear = df_clear.drop('Outside_Global_Index', axis=1)
    # 정규분포를 위한 log 변환

    log_list = [
        'X_Perimeter',
        'Y_Perimeter',
        'Steel_Plate_Thickness',
        # 'Edges_Index', # <- 0이 들어있어서 로그변환이 안됨 zerodivision_error
        'Outside_X_Index',
        'Area',
        'Edges_Y_Index',
        'Pixels_Areas',
        'Sum_of_Luminosity'
        ]

    for i in log_list:
        df_clear[i] = np.log(df_clear[i])

    y_list = list(df.iloc[:,-7:].columns)
    df_target = df.copy()
    df_target["Type"] = df_target.loc[:,y_list][y_list].idxmax(axis=1)
    df_target = df_target.drop(columns=y_list)

    # 이진분류를 위한 'Type' 컬럼 값 수정
    df_target1 = df_target.copy()
    df_target1['Type'] = df_target1['Type'].apply(lambda x: 1 if x != 'Other_Faults' else 0)
    df_target1['Type'].value_counts(normalize=True)

    ## 다중분류를 위한 'Type' 컬럼 값 수정
    #df_target2 = df_target.copy()
    ## 'Other_Faults'를 제외한 인덱스 가져오기
    #indices_to_remove = df_target2[df_target2['Type'] == 'Other_Faults'].index
    ## 해당 인덱스들을 제거하여 새로운 데이터프레임 생성
    #df_clear2 = df_clear.copy()
    #df_clear2 = df_clear.drop(indices_to_remove)
    ## 'Other_Faults' 행을 제외하고 결함이 있는 것만 남기기
    #df_target2 = df_target2[df_target2['Type'] != 'Other_Faults']
    #encoder = LabelEncoder()
    #df_target2['Type'] = encoder.fit_transform(df_target2['Type'])

    X = df_clear
    y = df_target1['Type']

    # 업스케일링
    # 스모트(SMOTE) 대신에 아다신(ADASYN) 사용된 이유는 좀 더 랜덤하게 업스케일링이 되게 하게 위해 사용
    if upsampling:
        adasyn = ADASYN(random_state=RANDOM_STATE)
        X, y = adasyn.fit_resample(X, y)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=y)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=VAL_SIZE, random_state=RANDOM_STATE, stratify=y_train)
    

    # MinMaxScaler - 0, StandardScaler - 1, , MaxAbsScaler - 2, RobustScaler - 3, Normalizer - 4
    if scaler == 0:
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    elif scaler == 1:
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    elif scaler == 2:
        scaler = MaxAbsScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    elif scaler == 3:
        scaler = RobustScaler()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    elif scaler == 4:
        scaler = Normalizer()
        X_train = scaler.fit_transform(X_train)
        X_val = scaler.transform(X_val)
        X_test = scaler.transform(X_test)
    else:
        pass
    
    X_train = pd.DataFrame(X_train, columns=X.columns)
    X_val = pd.DataFrame(X_val, columns=X.columns)
    X_test = pd.DataFrame(X_test, columns=X.columns)

    return X_train, X_val, X_test, y_train, y_val, y_test, scaler

# %%
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=0)
joblib.dump(scaler, 'MinMaxScaler.joblib')
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=1)
joblib.dump(scaler, 'StandardScaler.joblib')
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=2)
joblib.dump(scaler, 'MaxAbsScaler.joblib')
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=3)
joblib.dump(scaler, 'RobustScaler.joblib')
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=4)
joblib.dump(scaler, 'Normalizer.joblib')
# Out:
# ['Normalizer.joblib']

# %%
X_train, X_val, X_test, y_train, y_val, y_test, scaler = load_data(scaler=1, upsampling=1)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape, scaler
# Out:
# ((1580, 20), (396, 20), (494, 20), (1580,), (396,), (494,), StandardScaler())

# %%
X_train
# Out:
#       Pixels_Areas  X_Perimeter  Y_Perimeter  Sum_of_Luminosity  \
# 0         0.428385     0.249975     0.310458           0.422466
# 1         0.335572     0.235355     0.276147           0.342344
# 2         0.301028     0.199127     0.234801           0.309553
# 3         0.487295     0.399215     0.428764           0.478764
# 4         0.480345     0.389226     0.417512           0.535682
# ...            ...          ...          ...                ...
# 1236      0.369916     0.312360     0.282729           0.369076
# 1237      0.344327     0.175687     0.261555           0.375921
# 1238      0.318739     0.337616     0.253393           0.334518
# 1239      0.313655     0.199127     0.234801           0.316273
# 1240      0.714792     0.583315     0.502446           0.729251
#
#       Minimum_of_Luminosity  Maximum_of_Luminosity  Length_of_Conveyer  \
# 0                  0.220513               0.425926            0.299180
# 1                  0.543590               0.416667            0.280738
# 2                  0.548718               0.449074            0.264344
# 3                  0.420513               0.300926            0.952869
# 4                  0.394872               0.851852            0.327869
# ...                     ...                    ...                 ...
# 1236               0.492308               0.365741            0.272541
# 1237               0.656410               0.587963            0.327869
# 1238               0.615385               0.476852            0.256148
# 1239               0.482051               0.439815            0.944672
# 1240               0.215385               0.402778            0.264344
#
#       TypeOfSteel  Steel_Plate_Thickness  Edges_Index  Empty_Index  \
# 0             1.0               0.000000     0.715736     0.228732
# 1             1.0               0.454757     0.901728     0.444962
# 2             1.0               0.000000     0.084506     0.166437
# 3             1.0               1.000000     0.155647     0.747113
# 4             1.0               0.000000     0.788183     0.562242
# ...           ...                    ...          ...          ...
# 1236          1.0               0.000000     0.500904     0.464668
# 1237          1.0               0.000000     0.143388     0.190168
# 1238          1.0               0.000000     0.328477     0.706325
# 1239          0.0               0.201233     0.521503     0.258926
# 1240          1.0               0.000000     0.057777     0.483632
#
#       Square_Index  Outside_X_Index  Edges_X_Index  Edges_Y_Index  LogOfAreas  \
# 0         0.711909         0.311360       0.880682       1.000000    0.428390
# 1         0.663910         0.248424       0.661830       1.000000    0.335573
# 2         0.697489         0.195170       0.631088       1.000000    0.301022
# 3         0.379449         0.359378       0.401177       0.989976    0.487292
# 4         0.265100         0.319772       0.275264       0.994439    0.480349
# ...            ...              ...            ...            ...         ...
# 1236      0.628517         0.350654       0.650162       0.905001    0.369918
# 1237      0.689725         0.230202       1.000000       1.000000    0.344338
# 1238      0.369769         0.388354       0.661830       0.905001    0.318738
# 1239      0.899163         0.198161       0.815544       1.000000    0.313658
# 1240      0.366139         0.699415       0.587256       0.751376    0.714789
#
#       Orientation_Index  Luminosity_Index  SigmoidOfAreas      Area
# 0              0.643920          0.470011        0.456527  0.358230
# 1              0.667928          0.565196        0.166856  0.305697
# 2              0.651132          0.586382        0.063905  0.251734
# 3              0.810208          0.443229        0.999773  0.474398
# 4              0.867403          0.883126        0.984449  0.435941
# ...                 ...               ...             ...       ...
# 1236           0.314016          0.511631        0.294779  0.335344
# 1237           0.655016          0.734440        0.120658  0.288105
# 1238           0.184597          0.628065        0.273666  0.331515
# 1239           0.550260          0.546712        0.086720  0.269528
# 1240           0.182781          0.504212        1.000000  0.612177
#
# [1241 rows x 20 columns]

# %%
def get_metrics(model, x_train, y_train):

    # 교차 검증 수행 및 평가 지표 계산
    scoring = {
    'accuracy': 'accuracy',
    'recall': make_scorer(recall_score),
    'precision': make_scorer(precision_score),
    'f1_score': make_scorer(f1_score)
    }
    # 훈련 평가지표 출력
    model.fit(x_train, y_train)
    y_pred = model.predict(x_train)
    print("훈련 정확도: ", model.score(x_train, y_train))
    print("훈련 recall: ", recall_score(y_train, y_pred))
    print("훈련 Precision: ", precision_score(y_train, y_pred))
    print("훈련 F1-score: ", f1_score(y_train, y_pred))

    # 교차검증 5개로 분할
    cv_results = cross_validate(model, x_train, y_train, cv=5, scoring=scoring)
    
    # 교차 검증 결과를 데이터프레임으로 변환
    cv_results_df = pd.DataFrame(cv_results)
    
    # 평균값을 추가한 새로운 행을 생성하여 데이터프레임에 추가
    mean_scores = cv_results_df.mean().to_frame().T
    mean_scores.rename(index={0: 'mean'}, inplace=True)
    cv_results_df = pd.concat([cv_results_df, mean_scores], axis=0)

    return cv_results_df

# %%
def get_model1(nodes1 = 8, nodes2= 6, nodes3 = 4, drop_rate= 0.2, activation= 'relu'):
  # 모델 만들기
  # 뉴런의 개수는 input과 output 사이의 숫자를 넣으라고 한다. --> 사용, 왜냐하면 시간이 적게 걸려서
  # 뉴런의 개수는 input의 2/3 정도 넣라고 한다.
  # 뉴런의 개수는 input의 두배보다는 적게 넣라고 한다.
  regularizer = L1L2(l1=0.001, l2=0.001)

  model = Sequential([Layer.Dense(12, input_shape=(20,))])
  model.add(Layer.Dense(nodes1, activation = activation, kernel_regularizer=regularizer))
  model.add(Layer.BatchNormalization())
  model.add(Layer.Dropout(drop_rate))

  model.add(Layer.Dense(nodes2, activation = activation, kernel_regularizer=regularizer))
  model.add(Layer.BatchNormalization())
  model.add(Layer.Dropout(drop_rate))

  model.add(Layer.Dense(nodes3, activation = activation, kernel_regularizer=regularizer))
  model.add(Layer.BatchNormalization())
  model.add(Layer.Dropout(drop_rate))

  model.add(Layer.Dense(1, activation = 'sigmoid'))

  # metrics에는 1이 나오는 recall 이랑 acc만 중요하다.
  metrics = [
      Recall(name = 'recall'),
      Precision(name = 'precision'),
      BinaryAccuracy(name = 'binary accuracy') # Accuracy를 사용 안 하는 이유는 Accuracy가 이상하세 나왔기 때문.
  ]

  model.compile(optimizer = 'adam',
                loss='binary_crossentropy',
                metrics = metrics)

  return model

# %%
def get_model2():
    model = Sequential()
    model.add(Layer.Dense(256, activation='relu'))
    model.add(Layer.Dense(256, activation='relu'))
    model.add(Layer.Dense(1, activation='sigmoid'))

    model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy'])

    return model

# %%
class TimingCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        print("Starting training")
        self.starttime = timer()

    def on_train_end(self, logs=None):
        print("End of training, took {} seconds".format(timer()-self.starttime))

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 10 == 0:
          print("Epoch is {} and {} seconds passed".format(epoch, timer()-self.starttime))

# %%
check_path = 'model_weights.h5'

callback = [
    #tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=50),
    tf.keras.callbacks.ModelCheckpoint(filepath=check_path, save_weights_only=True, monitor='val_loss', mode='min', save_best_only=True),
    #tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=200, min_lr=0.001),
    TimingCallback()
]

# %%
model1 = get_model1()

# %%
model2 = get_model2()

# %%
history1 = model1.fit(X_train, y_train, batch_size= 1024, epochs= 1000,  validation_data=(X_val, y_val),callbacks=callback, verbose = 0)
# Out:
# Starting training
# Epoch is 0 and 0.04754120809957385 seconds passed
# Epoch is 10 and 0.213104666210711 seconds passed
# Epoch is 20 and 0.37147129117511213 seconds passed
# Epoch is 30 and 0.5222185000311583 seconds passed
# Epoch is 40 and 0.6805434999987483 seconds passed
# Epoch is 50 and 0.8306591662112623 seconds passed
# Epoch is 60 and 0.9791686660610139 seconds passed
# Epoch is 70 and 1.1553187081590295 seconds passed
# Epoch is 80 and 1.3133613751269877 seconds passed
# Epoch is 90 and 1.4753460411448032 seconds passed
# Epoch is 100 and 1.6494560830760747 seconds passed
# Epoch is 110 and 1.805825041141361 seconds passed
# Epoch is 120 and 1.9517773331608623 seconds passed
# Epoch is 130 and 2.112878500018269 seconds passed
# Epoch is 140 and 2.26979725016281 seconds passed
# Epoch is 150 and 2.424461083021015 seconds passed
# Epoch is 160 and 2.578341916203499 seconds passed
# Epoch is 170 and 2.732729708077386 seconds passed
# Epoch is 180 and 2.8851344999857247 seconds passed
# Epoch is 190 and 3.0317613331135362 seconds passed
# Epoch is 200 and 3.186773916007951 seconds passed
# Epoch is 210 and 3.3422032080125064 seconds passed
# Epoch is 220 and 3.4988542911596596 seconds passed
# Epoch is 230 and 3.6520127500407398 seconds passed
# Epoch is 240 and 3.804060250055045 seconds passed
# Epoch is 250 and 3.97308479109779 seconds passed
# Epoch is 260 and 4.12454037507996 seconds passed
# Epoch is 270 and 4.272696041036397 seconds passed
# Epoch is 280 and 4.418836583150551 seconds passed
# Epoch is 290 and 4.5675607500597835 seconds passed
# Epoch is 300 and 4.714211041107774 seconds passed
# Epoch is 310 and 4.861976250074804 seconds passed
# Epoch is 320 and 5.009438958019018 seconds passed
# Epoch is 330 and 5.155662250006571 seconds passed
# Epoch is 340 and 5.299860833212733 seconds passed
# Epoch is 350 and 5.446186583023518 seconds passed
# Epoch is 360 and 5.59113641618751 seconds passed
# Epoch is 370 and 5.7382068750448525 seconds passed
# Epoch is 380 and 5.885715583106503 seconds passed
# Epoch is 390 and 6.0359335001558065 seconds passed
# Epoch is 400 and 6.184309083037078 seconds passed
# Epoch is 410 and 6.327612541150302 seconds passed
# Epoch is 420 and 6.471888708183542 seconds passed
# Epoch is 430 and 6.620274791028351 seconds passed
# Epoch is 440 and 6.76456870813854 seconds passed
# Epoch is 450 and 6.910893666092306 seconds passed
# Epoch is 460 and 7.06080645811744 seconds passed
# Epoch is 470 and 7.204549583140761 seconds passed
# Epoch is 480 and 7.347613500198349 seconds passed
# Epoch is 490 and 7.492120541166514 seconds passed
# Epoch is 500 and 7.636367875151336 seconds passed
# Epoch is 510 and 7.783531625056639 seconds passed
# Epoch is 520 and 7.928931458154693 seconds passed
# Epoch is 530 and 8.077717583160847 seconds passed
# Epoch is 540 and 8.224187083076686 seconds passed
# Epoch is 550 and 8.377198625123128 seconds passed
# Epoch is 560 and 8.527817500056699 seconds passed
# Epoch is 570 and 8.67105266614817 seconds passed
# Epoch is 580 and 8.818624790990725 seconds passed
# Epoch is 590 and 8.965865541016683 seconds passed
# Epoch is 600 and 9.109819125151262 seconds passed
# Epoch is 610 and 9.259115166030824 seconds passed
# Epoch is 620 and 9.406419625040144 seconds passed
# Epoch is 630 and 9.556216333061457 seconds passed
# Epoch is 640 and 9.702927166130394 seconds passed
# Epoch is 650 and 9.8555971251335 seconds passed
# Epoch is 660 and 10.001493750140071 seconds passed
# Epoch is 670 and 10.150665541179478 seconds passed
# Epoch is 680 and 10.295533833093941 seconds passed
# Epoch is 690 and 10.448657250031829 seconds passed
# Epoch is 700 and 10.60253525013104 seconds passed
# Epoch is 710 and 10.749143458204344 seconds passed
# Epoch is 720 and 10.893652333179489 seconds passed
# Epoch is 730 and 11.038248166209087 seconds passed
# Epoch is 740 and 11.183817166136578 seconds passed
# Epoch is 750 and 11.329831791110337 seconds passed
# Epoch is 760 and 11.473311291076243 seconds passed
# Epoch is 770 and 11.619236291153356 seconds passed
# Epoch is 780 and 11.764590915990993 seconds passed
# Epoch is 790 and 11.910608750069514 seconds passed
# Epoch is 800 and 12.055956583004445 seconds passed
# Epoch is 810 and 12.20067450008355 seconds passed
# Epoch is 820 and 12.344689875142649 seconds passed
# Epoch is 830 and 12.491398458136246 seconds passed
# Epoch is 840 and 12.637175208190456 seconds passed
# Epoch is 850 and 12.781308458186686 seconds passed
# Epoch is 860 and 12.926993583096191 seconds passed
# Epoch is 870 and 13.072669791057706 seconds passed
# Epoch is 880 and 13.217219875194132 seconds passed
# Epoch is 890 and 13.366196958115324 seconds passed
# Epoch is 900 and 13.515991416061297 seconds passed
# Epoch is 910 and 13.662087708013132 seconds passed
# Epoch is 920 and 13.807313416153193 seconds passed
# Epoch is 930 and 13.956425875192508 seconds passed
# Epoch is 940 and 14.103611333062872 seconds passed
# Epoch is 950 and 14.251048083184287 seconds passed
# Epoch is 960 and 14.401526833185926 seconds passed
# Epoch is 970 and 14.55899712513201 seconds passed
# Epoch is 980 and 14.705757916206494 seconds passed
# Epoch is 990 and 14.854377416195348 seconds passed
# End of training, took 14.991876875050366 seconds

# %%
results = model1.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5498 - recall: 0.5787 - precision: 0.8400 - binary accuracy: 0.7267

# %%
    # results = model.fit(x_train1, y_train1, batch_size = 64, epochs=500)
history2 = model2.fit(X_train, y_train, batch_size= 64, epochs= 500, verbose = 1, callbacks=callback)
# Out:
# Starting training
# Epoch 1/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.1277e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 0 and 0.04241558420471847 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 5.5549e-05 - accuracy: 1.0000
# Epoch 2/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.9364e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.3474e-05 - accuracy: 1.0000
# Epoch 3/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.1982e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.4712e-05 - accuracy: 1.0000
# Epoch 4/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.9517e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.3892e-05 - accuracy: 1.0000
# Epoch 5/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.7518e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.5526e-05 - accuracy: 1.0000
# Epoch 6/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.4838e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.7841e-05 - accuracy: 1.0000
# Epoch 7/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.6211e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.3312e-05 - accuracy: 1.0000
# Epoch 8/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1230e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.3477e-05 - accuracy: 1.0000
# Epoch 9/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.9324e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.9087e-05 - accuracy: 1.0000
# Epoch 10/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1039e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.8739e-05 - accuracy: 1.0000
# Epoch 11/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.8391e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 10 and 0.33867841702885926 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 5.2659e-05 - accuracy: 1.0000
# Epoch 12/500
# 21/25 [========================>.....] - ETA: 0s - loss: 5.5261e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 5.1651e-05 - accuracy: 1.0000
# Epoch 13/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.3559e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 5.4760e-05 - accuracy: 1.0000
# Epoch 14/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.5484e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.8902e-05 - accuracy: 1.0000
# Epoch 15/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7205e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.9383e-05 - accuracy: 1.0000
# Epoch 16/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5862e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.7278e-05 - accuracy: 1.0000
# Epoch 17/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.1424e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.8792e-05 - accuracy: 1.0000
# Epoch 18/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3732e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.1322e-05 - accuracy: 1.0000
# Epoch 19/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6079e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.9948e-05 - accuracy: 1.0000
# Epoch 20/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.8331e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.6403e-05 - accuracy: 1.0000
# Epoch 21/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.2084e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 20 and 0.6793590001761913 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 4.2853e-05 - accuracy: 1.0000
# Epoch 22/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.4232e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.2841e-05 - accuracy: 1.0000
# Epoch 23/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.1197e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.3594e-05 - accuracy: 1.0000
# Epoch 24/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.3274e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.2231e-05 - accuracy: 1.0000
# Epoch 25/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3972e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.3171e-05 - accuracy: 1.0000
# Epoch 26/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8361e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.3006e-05 - accuracy: 1.0000
# Epoch 27/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7710e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 4.0300e-05 - accuracy: 1.0000
# Epoch 28/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1978e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 4.3180e-05 - accuracy: 1.0000
# Epoch 29/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.6436e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 4.6304e-05 - accuracy: 1.0000
# Epoch 30/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.8214e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 5.5623e-05 - accuracy: 1.0000
# Epoch 31/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.0594e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 30 and 1.047366000013426 seconds passed
# 25/25 [==============================] - 0s 2ms/step - loss: 4.0107e-05 - accuracy: 1.0000
# Epoch 32/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.9283e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.9436e-05 - accuracy: 1.0000
# Epoch 33/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.4880e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7935e-05 - accuracy: 1.0000
# Epoch 34/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.3033e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.6897e-05 - accuracy: 1.0000
# Epoch 35/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.7920e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.6760e-05 - accuracy: 1.0000
# Epoch 36/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3023e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.8098e-05 - accuracy: 1.0000
# Epoch 37/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5525e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.5900e-05 - accuracy: 1.0000
# Epoch 38/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.3409e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.5642e-05 - accuracy: 1.0000
# Epoch 39/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.1979e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7771e-05 - accuracy: 1.0000
# Epoch 40/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.5194e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7253e-05 - accuracy: 1.0000
# Epoch 41/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.1582e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 40 and 1.3344181252177805 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 3.4536e-05 - accuracy: 1.0000
# Epoch 42/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.4467e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.4393e-05 - accuracy: 1.0000
# Epoch 43/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.7692e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 987us/step - loss: 3.3679e-05 - accuracy: 1.0000
# Epoch 44/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9030e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.3554e-05 - accuracy: 1.0000
# Epoch 45/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.7068e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.3263e-05 - accuracy: 1.0000
# Epoch 46/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.9940e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.8197e-05 - accuracy: 1.0000
# Epoch 47/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.8353e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.2693e-05 - accuracy: 1.0000
# Epoch 48/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8811e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.3519e-05 - accuracy: 1.0000
# Epoch 49/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0139e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.5471e-05 - accuracy: 1.0000
# Epoch 50/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.1737e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.3546e-05 - accuracy: 1.0000
# Epoch 51/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3755e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 50 and 1.6137714171782136 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 3.3449e-05 - accuracy: 1.0000
# Epoch 52/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.2927e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.1340e-05 - accuracy: 1.0000
# Epoch 53/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.1927e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.1159e-05 - accuracy: 1.0000
# Epoch 54/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.3217e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0873e-05 - accuracy: 1.0000
# Epoch 55/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8560e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9810e-05 - accuracy: 1.0000
# Epoch 56/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.2766e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0207e-05 - accuracy: 1.0000
# Epoch 57/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.6470e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0015e-05 - accuracy: 1.0000
# Epoch 58/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.3077e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 2.9240e-05 - accuracy: 1.0000
# Epoch 59/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.2880e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0130e-05 - accuracy: 1.0000
# Epoch 60/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5926e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9358e-05 - accuracy: 1.0000
# Epoch 61/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.4874e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 60 and 1.9335840421263129 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9855e-05 - accuracy: 1.0000
# Epoch 62/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.4817e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9338e-05 - accuracy: 1.0000
# Epoch 63/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7440e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8044e-05 - accuracy: 1.0000
# Epoch 64/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.5376e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8118e-05 - accuracy: 1.0000
# Epoch 65/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.2167e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9021e-05 - accuracy: 1.0000
# Epoch 66/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3269e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.7273e-05 - accuracy: 1.0000
# Epoch 67/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.2273e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8210e-05 - accuracy: 1.0000
# Epoch 68/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.3915e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9437e-05 - accuracy: 1.0000
# Epoch 69/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1409e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.5523e-05 - accuracy: 1.0000
# Epoch 70/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7526e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 949us/step - loss: 2.6527e-05 - accuracy: 1.0000
# Epoch 71/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1290e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 70 and 2.225828417111188 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 2.9510e-05 - accuracy: 1.0000
# Epoch 72/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.5679e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8210e-05 - accuracy: 1.0000
# Epoch 73/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.0143e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.5269e-05 - accuracy: 1.0000
# Epoch 74/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1284e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.5763e-05 - accuracy: 1.0000
# Epoch 75/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6796e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.4629e-05 - accuracy: 1.0000
# Epoch 76/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7926e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.4574e-05 - accuracy: 1.0000
# Epoch 77/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.5717e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3999e-05 - accuracy: 1.0000
# Epoch 78/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6586e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3389e-05 - accuracy: 1.0000
# Epoch 79/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.1985e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3569e-05 - accuracy: 1.0000
# Epoch 80/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.0843e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3447e-05 - accuracy: 1.0000
# Epoch 81/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1139e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 80 and 2.5313066670205444 seconds passed
# 25/25 [==============================] - 0s 2ms/step - loss: 2.2893e-05 - accuracy: 1.0000
# Epoch 82/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.6492e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.1689e-05 - accuracy: 1.0000
# Epoch 83/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6787e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0402e-05 - accuracy: 1.0000
# Epoch 84/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.2981e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.4143e-05 - accuracy: 1.0000
# Epoch 85/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.5951e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.2603e-05 - accuracy: 1.0000
# Epoch 86/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0536e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.1718e-05 - accuracy: 1.0000
# Epoch 87/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.4917e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.4001e-05 - accuracy: 1.0000
# Epoch 88/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.9112e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 949us/step - loss: 3.7899e-05 - accuracy: 1.0000
# Epoch 89/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.9048e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 6.9701e-05 - accuracy: 1.0000
# Epoch 90/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6112e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3775e-04 - accuracy: 1.0000
# Epoch 91/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7543e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 90 and 2.818373209098354 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9854
# Epoch 92/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.5397 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 0.9348
# Epoch 93/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.1335 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.9247
# Epoch 94/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.1229 - accuracy: 0.9531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2187 - accuracy: 0.9589
# Epoch 95/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.0594 - accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9734
# Epoch 96/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1549 - accuracy: 0.9759
# Epoch 97/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.1414 - accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0449 - accuracy: 0.9835
# Epoch 98/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9968
# Epoch 99/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 0.9975
# Epoch 100/500
#  1/25 [>.............................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 101/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.2432e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 100 and 3.109342792071402 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 4.9128e-04 - accuracy: 1.0000
# Epoch 102/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.8196e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.7037e-04 - accuracy: 1.0000
# Epoch 103/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.2359e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 3.3415e-04 - accuracy: 1.0000
# Epoch 104/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.0935e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 3.1401e-04 - accuracy: 1.0000
# Epoch 105/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1441e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 3.0208e-04 - accuracy: 1.0000
# Epoch 106/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.3900e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.8418e-04 - accuracy: 1.0000
# Epoch 107/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.8534e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.7311e-04 - accuracy: 1.0000
# Epoch 108/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.9339e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.6284e-04 - accuracy: 1.0000
# Epoch 109/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9017e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 945us/step - loss: 2.5377e-04 - accuracy: 1.0000
# Epoch 110/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.3663e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 994us/step - loss: 2.4664e-04 - accuracy: 1.0000
# Epoch 111/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.0990e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 110 and 3.4150060419924557 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3839e-04 - accuracy: 1.0000
# Epoch 112/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.3866e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.3366e-04 - accuracy: 1.0000
# Epoch 113/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.4299e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.2636e-04 - accuracy: 1.0000
# Epoch 114/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5658e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.2034e-04 - accuracy: 1.0000
# Epoch 115/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.0691e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.1689e-04 - accuracy: 1.0000
# Epoch 116/500
# 24/25 [===========================>..] - ETA: 0s - loss: 2.1095e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 2.1104e-04 - accuracy: 1.0000
# Epoch 117/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.0550e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.0596e-04 - accuracy: 1.0000
# Epoch 118/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.7721e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 2.0176e-04 - accuracy: 1.0000
# Epoch 119/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1035e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.9764e-04 - accuracy: 1.0000
# Epoch 120/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.7930e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.9549e-04 - accuracy: 1.0000
# Epoch 121/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0678e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 120 and 3.7260285841766745 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.9030e-04 - accuracy: 1.0000
# Epoch 122/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.5758e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.8705e-04 - accuracy: 1.0000
# Epoch 123/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6295e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.8444e-04 - accuracy: 1.0000
# Epoch 124/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.5890e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 996us/step - loss: 1.8144e-04 - accuracy: 1.0000
# Epoch 125/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9411e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7889e-04 - accuracy: 1.0000
# Epoch 126/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.0590e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7595e-04 - accuracy: 1.0000
# Epoch 127/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8893e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7273e-04 - accuracy: 1.0000
# Epoch 128/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8307e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.7067e-04 - accuracy: 1.0000
# Epoch 129/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6309e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.6734e-04 - accuracy: 1.0000
# Epoch 130/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.2353e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.6535e-04 - accuracy: 1.0000
# Epoch 131/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5377e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 130 and 4.012301292037591 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.6279e-04 - accuracy: 1.0000
# Epoch 132/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9013e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.6028e-04 - accuracy: 1.0000
# Epoch 133/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.4823e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.5844e-04 - accuracy: 1.0000
# Epoch 134/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6851e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.5599e-04 - accuracy: 1.0000
# Epoch 135/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7548e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.5427e-04 - accuracy: 1.0000
# Epoch 136/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.8005e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.5203e-04 - accuracy: 1.0000
# Epoch 137/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.2231e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4990e-04 - accuracy: 1.0000
# Epoch 138/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7490e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4819e-04 - accuracy: 1.0000
# Epoch 139/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.5140e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4668e-04 - accuracy: 1.0000
# Epoch 140/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.2929e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4533e-04 - accuracy: 1.0000
# Epoch 141/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.1490e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 140 and 4.320957167074084 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4283e-04 - accuracy: 1.0000
# Epoch 142/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.6642e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4115e-04 - accuracy: 1.0000
# Epoch 143/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1252e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.4019e-04 - accuracy: 1.0000
# Epoch 144/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.0100e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3807e-04 - accuracy: 1.0000
# Epoch 145/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.7293e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3687e-04 - accuracy: 1.0000
# Epoch 146/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9235e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3497e-04 - accuracy: 1.0000
# Epoch 147/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.5006e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3344e-04 - accuracy: 1.0000
# Epoch 148/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.0313e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3219e-04 - accuracy: 1.0000
# Epoch 149/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.3126e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3052e-04 - accuracy: 1.0000
# Epoch 150/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.8796e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.3025e-04 - accuracy: 1.0000
# Epoch 151/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.5357e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 150 and 4.631553667131811 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2778e-04 - accuracy: 1.0000
# Epoch 152/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.2802e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2694e-04 - accuracy: 1.0000
# Epoch 153/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.4407e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2537e-04 - accuracy: 1.0000
# Epoch 154/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.2573e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2454e-04 - accuracy: 1.0000
# Epoch 155/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.3869e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2281e-04 - accuracy: 1.0000
# Epoch 156/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6845e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2262e-04 - accuracy: 1.0000
# Epoch 157/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1039e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2022e-04 - accuracy: 1.0000
# Epoch 158/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7010e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2050e-04 - accuracy: 1.0000
# Epoch 159/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6238e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1821e-04 - accuracy: 1.0000
# Epoch 160/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.8212e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1713e-04 - accuracy: 1.0000
# Epoch 161/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.1591e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 160 and 4.933676459128037 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1654e-04 - accuracy: 1.0000
# Epoch 162/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1601e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1597e-04 - accuracy: 1.0000
# Epoch 163/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.7110e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1518e-04 - accuracy: 1.0000
# Epoch 164/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.8913e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1330e-04 - accuracy: 1.0000
# Epoch 165/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.4689e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1258e-04 - accuracy: 1.0000
# Epoch 166/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.6598e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1140e-04 - accuracy: 1.0000
# Epoch 167/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.4248e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1218e-04 - accuracy: 1.0000
# Epoch 168/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3665e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0913e-04 - accuracy: 1.0000
# Epoch 169/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.0977e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0867e-04 - accuracy: 1.0000
# Epoch 170/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.7173e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0746e-04 - accuracy: 1.0000
# Epoch 171/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.7001e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 170 and 5.2183151671197265 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0637e-04 - accuracy: 1.0000
# Epoch 172/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3348e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 958us/step - loss: 1.0596e-04 - accuracy: 1.0000
# Epoch 173/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.3220e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0519e-04 - accuracy: 1.0000
# Epoch 174/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.5783e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0393e-04 - accuracy: 1.0000
# Epoch 175/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.6082e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# Epoch 443/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.5839e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3973e-05 - accuracy: 1.0000
# Epoch 444/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.6350e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3788e-05 - accuracy: 1.0000
# Epoch 445/500
# 21/25 [========================>.....] - ETA: 0s - loss: 1.2728e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.3671e-05 - accuracy: 1.0000
# Epoch 446/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.3229e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3618e-05 - accuracy: 1.0000
# Epoch 447/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.9710e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3294e-05 - accuracy: 1.0000
# Epoch 448/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.9789e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3232e-05 - accuracy: 1.0000
# Epoch 449/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.8662e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.3658e-05 - accuracy: 1.0000
# Epoch 450/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.8856e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 982us/step - loss: 1.4296e-05 - accuracy: 1.0000
# Epoch 451/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.0081e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 450 and 13.747104042209685 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2688e-05 - accuracy: 1.0000
# Epoch 452/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.2148e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2637e-05 - accuracy: 1.0000
# Epoch 453/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.1433e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2395e-05 - accuracy: 1.0000
# Epoch 454/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.8567e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2065e-05 - accuracy: 1.0000
# Epoch 455/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3260e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2535e-05 - accuracy: 1.0000
# Epoch 456/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.5012e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1790e-05 - accuracy: 1.0000
# Epoch 457/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.5973e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2146e-05 - accuracy: 1.0000
# Epoch 458/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.6868e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.2112e-05 - accuracy: 1.0000
# Epoch 459/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.0046e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.3439e-05 - accuracy: 1.0000
# Epoch 460/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.0749e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 953us/step - loss: 1.1549e-05 - accuracy: 1.0000
# Epoch 461/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.5044e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 460 and 14.064691084204242 seconds passed
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1626e-05 - accuracy: 1.0000
# Epoch 462/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.6986e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1618e-05 - accuracy: 1.0000
# Epoch 463/500
#  1/25 [>.............................] - ETA: 0s - loss: 9.3419e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1097e-05 - accuracy: 1.0000
# Epoch 464/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0847e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1393e-05 - accuracy: 1.0000
# Epoch 465/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.9137e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 951us/step - loss: 1.1322e-05 - accuracy: 1.0000
# Epoch 466/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.1084e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1696e-05 - accuracy: 1.0000
# Epoch 467/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1936e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0761e-05 - accuracy: 1.0000
# Epoch 468/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.5717e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0755e-05 - accuracy: 1.0000
# Epoch 469/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.2987e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 995us/step - loss: 1.0648e-05 - accuracy: 1.0000
# Epoch 470/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1713e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0412e-05 - accuracy: 1.0000
# Epoch 471/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.3807e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 470 and 14.35974141699262 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0538e-05 - accuracy: 1.0000
# Epoch 472/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.4768e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0931e-05 - accuracy: 1.0000
# Epoch 473/500
# 19/25 [=====================>........] - ETA: 0s - loss: 1.1713e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1006e-05 - accuracy: 1.0000
# Epoch 474/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.0288e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.1096e-05 - accuracy: 1.0000
# Epoch 475/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.7720e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 967us/step - loss: 1.0452e-05 - accuracy: 1.0000
# Epoch 476/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.1091e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.9612e-06 - accuracy: 1.0000
# Epoch 477/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.7465e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0239e-05 - accuracy: 1.0000
# Epoch 478/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.4403e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 1.0736e-05 - accuracy: 1.0000
# Epoch 479/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7524e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 983us/step - loss: 9.5742e-06 - accuracy: 1.0000
# Epoch 480/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.4624e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.9130e-06 - accuracy: 1.0000
# Epoch 481/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0916e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 480 and 14.687251167139038 seconds passed
# 25/25 [==============================] - 0s 1ms/step - loss: 1.0429e-05 - accuracy: 1.0000
# Epoch 482/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.4426e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.4875e-06 - accuracy: 1.0000
# Epoch 483/500
#  1/25 [>.............................] - ETA: 0s - loss: 3.4302e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 986us/step - loss: 9.4878e-06 - accuracy: 1.0000
# Epoch 484/500
#  1/25 [>.............................] - ETA: 0s - loss: 8.4577e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.4576e-06 - accuracy: 1.0000
# Epoch 485/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.3327e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 959us/step - loss: 9.1225e-06 - accuracy: 1.0000
# Epoch 486/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.5338e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.5236e-06 - accuracy: 1.0000
# Epoch 487/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1095e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.8282e-06 - accuracy: 1.0000
# Epoch 488/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.9665e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 8.6724e-06 - accuracy: 1.0000
# Epoch 489/500
#  1/25 [>.............................] - ETA: 0s - loss: 4.0509e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.7153e-06 - accuracy: 1.0000
# Epoch 490/500
# 23/25 [==========================>...] - ETA: 0s - loss: 9.3429e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 8.8815e-06 - accuracy: 1.0000
# Epoch 491/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.1175e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch is 490 and 15.00779787520878 seconds passed
# 25/25 [==============================] - 0s 988us/step - loss: 8.3322e-06 - accuracy: 1.0000
# Epoch 492/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7522e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.4540e-06 - accuracy: 1.0000
# Epoch 493/500
#  1/25 [>.............................] - ETA: 0s - loss: 7.2251e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.2203e-06 - accuracy: 1.0000
# Epoch 494/500
#  1/25 [>.............................] - ETA: 0s - loss: 6.6682e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 987us/step - loss: 1.0146e-05 - accuracy: 1.0000
# Epoch 495/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.2790e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 9.1568e-06 - accuracy: 1.0000
# Epoch 496/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.0779e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.8137e-06 - accuracy: 1.0000
# Epoch 497/500
#  1/25 [>.............................] - ETA: 0s - loss: 5.3584e-06 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 2ms/step - loss: 8.1385e-06 - accuracy: 1.0000
# Epoch 498/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.6783e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 960us/step - loss: 8.3039e-06 - accuracy: 1.0000
# Epoch 499/500
#  1/25 [>.............................] - ETA: 0s - loss: 1.7335e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.2826e-06 - accuracy: 1.0000
# Epoch 500/500
#  1/25 [>.............................] - ETA: 0s - loss: 2.3810e-05 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 25/25 [==============================] - 0s 1ms/step - loss: 8.7099e-06 - accuracy: 1.0000
# End of training, took 15.273388584144413 seconds

# %%
model2.save('model_layers')
# Out:
# INFO:tensorflow:Assets written to: model_layers/assets
# INFO:tensorflow:Assets written to: model_layers/assets

# %%
results = model2.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 546us/step - loss: 2.3738 - accuracy: 0.8441
